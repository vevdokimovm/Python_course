# %% [markdown]
# Вам дана в архиве (ссылка) файловая структура, состоящая из директорий и файлов.
#
# Вам необходимо распаковать этот архив, и затем найти в данной в файловой структуре все директории, в которых есть хотя бы один файл с расширением ".py".
#
# Ответом на данную задачу будет являться файл со списком таких директорий, отсортированных в лексикографическом порядке.
#
# Для лучшего понимания формата задачи, ознакомьтесь с примером.
# Пример архива
# Пример ответа

# %%
import os
import re

answer = []
f = open("main_ans.txt", "w")

for current_dir, dirs, files in os.walk("main/"):
    print("current_dir = ", current_dir)
    print("dirs = ", dirs)
    print("files = ", files)
    
    pattern = r".*\.py$"
    for file in files:
        print("** file = ", file)
        if re.match(pattern, file):
            answer.append(current_dir)
            break
        
answer.sort()
print("answer = ", answer)

for ans in answer:
    f.write(ans)
    f.write('\n')
    
f.close()
# Out:
# current_dir =  main/
# dirs =  ['uvvuz', 'qkseh', 'taivr', 'tgwey', 'ksuvk', 'mwhci', 'frtrl', 'ddiqo', 'olmhl', 'lqbli', 'jrczb', 'wkwll', 'ybebm', 'zduna', 'afkgv', 'hgyoc', 'sitdc', 'zyczx']
# files =  ['xmffa.txt', 'myjqk.py', 'rpuyq.txt', 'oizxq.txt', 'qcdrm.py', 'lmrrz.txt', 'sgeru.txt', 'aelpx.txt', 'kqgeg.txt', 'soldv.txt', 'rlvgd.txt', 'wvere.txt', 'yvgwm.py', 'nrlqk.py', 'ivdfa.txt', 'yohuh.txt', 'qhjmz.txt', 'zgwye.txt', 'wxhtw.py', 'sidxx.txt', 'vaxyw.txt', 'fjcnm.py', 'mdwam.txt', 'fpyfb.py', 'nelpv.py', 'qdbhh.txt', 'ivcpr.txt', 'qbarq.txt', 'lzccb.py', 'ivkih.txt', 'mwgax.txt', 'iwohr.py', 'iswbd.txt', 'dshyt.txt', 'jogpz.py', 'suvtu.py']
# ** file =  xmffa.txt
# ** file =  myjqk.py
# current_dir =  main/uvvuz
# dirs =  ['ksnof', 'bdtyv']
# files =  ['bmuav.py', 'dcfnq.txt', 'xxuhp.txt', 'ksfjq.py']
# ** file =  bmuav.py
# current_dir =  main/uvvuz/ksnof
# dirs =  []
# files =  ['vjvey.py', 'ylmqp.txt']
# ** file =  vjvey.py
# current_dir =  main/uvvuz/bdtyv
# dirs =  []
# files =  ['yhbfx.txt', 'sjhfg.txt', 'sztlk.txt', 'gldex.txt', 'gpwna.txt']
# ** file =  yhbfx.txt
# ** file =  sjhfg.txt
# ** file =  sztlk.txt
# ** file =  gldex.txt
# ** file =  gpwna.txt
# current_dir =  main/qkseh
# dirs =  ['uxhxb']
# files =  ['mmvbh.py', 'levqj.txt', 'sxtth.txt', 'fdfju.py', 'wecoy.txt']
# ** file =  mmvbh.py
# current_dir =  main/qkseh/uxhxb
# dirs =  ['mwaqm']
# files =  ['dkpkp.txt']
# ** file =  dkpkp.txt
# current_dir =  main/qkseh/uxhxb/mwaqm
# dirs =  []
# files =  ['fcncy.txt']
# ** file =  fcncy.txt
# current_dir =  main/taivr
# dirs =  ['bcsow', 'yptwa']
# files =  ['qcwfi.txt', 'nvbgf.py']
# ** file =  qcwfi.txt
# ** file =  nvbgf.py
# current_dir =  main/taivr/bcsow
# dirs =  []
# files =  ['nhhlc.txt', 'ceqnw.py', 'ajvsh.txt', 'rqxod.txt', 'otmzp.txt', 'pmcca.txt', 'tfcnd.txt']
# ** file =  nhhlc.txt
# ** file =  ceqnw.py
# current_dir =  main/taivr/yptwa
# dirs =  ['xsbzr']
# files =  []
# current_dir =  main/taivr/yptwa/xsbzr
# dirs =  ['hcasz', 'armfl']
# files =  ['dcwkh.txt', 'podph.txt', 'xtrwo.txt', 'tpzyb.py']
# ** file =  dcwkh.txt
# ** file =  podph.txt
# ** file =  xtrwo.txt
# ** file =  tpzyb.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz
# dirs =  ['ilitr']
# files =  []
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr
# dirs =  ['joejy', 'urguw']
# files =  ['jvkxo.txt']
# ** file =  jvkxo.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/joejy
# dirs =  ['bjusr']
# files =  ['cewmk.py']
# ** file =  cewmk.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/joejy/bjusr
# dirs =  []
# files =  []
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw
# dirs =  ['sjmeg']
# files =  ['zxfpt.txt', 'twpgm.txt']
# ** file =  zxfpt.txt
# ** file =  twpgm.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg
# dirs =  ['ddnaa']
# files =  ['sqlda.txt', 'xsukp.txt']
# ** file =  sqlda.txt
# ** file =  xsukp.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa
# dirs =  ['lszec', 'jxhbl', 'ckaab']
# files =  ['rvzwp.py', 'ghojr.txt', 'hcyqp.txt', 'bffrb.py', 'eihky.txt', 'xpjax.txt', 'hyuxj.txt', 'lshgy.py']
# ** file =  rvzwp.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/lszec
# dirs =  ['ncdyy', 'ofdms', 'wdftb']
# files =  ['gaslh.txt', 'pmxrs.py', 'pudrf.txt', 'sknss.py', 'dhkcg.txt', 'jleiq.py']
# ** file =  gaslh.txt
# ** file =  pmxrs.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/lszec/ncdyy
# dirs =  []
# files =  ['jqivk.txt', 'rhozk.txt']
# ** file =  jqivk.txt
# ** file =  rhozk.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/lszec/ofdms
# dirs =  []
# files =  ['jppbd.txt', 'jxjlk.txt', 'knzps.txt']
# ** file =  jppbd.txt
# ** file =  jxjlk.txt
# ** file =  knzps.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/lszec/wdftb
# dirs =  ['fajay', 'mhqps']
# files =  ['jcxov.txt', 'opzlf.txt', 'crwkr.txt', 'ziwlw.txt', 'brmmp.txt', 'chdnu.txt']
# ** file =  jcxov.txt
# ** file =  opzlf.txt
# ** file =  crwkr.txt
# ** file =  ziwlw.txt
# ** file =  brmmp.txt
# ** file =  chdnu.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/lszec/wdftb/fajay
# dirs =  []
# files =  ['mkydb.txt', 'wcdub.txt']
# ** file =  mkydb.txt
# ** file =  wcdub.txt
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/lszec/wdftb/mhqps
# dirs =  []
# files =  ['alktd.txt', 'vkvkp.py', 'uqqxx.py']
# ** file =  alktd.txt
# ** file =  vkvkp.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/jxhbl
# dirs =  ['lradw', 'tpdvr']
# files =  []
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/jxhbl/lradw
# dirs =  ['iglcm']
# files =  ['izvpu.txt', 'gxkwi.txt', 'zidfs.txt', 'zlyuw.txt', 'dnjsf.py']
# ** file =  izvpu.txt
# ** file =  gxkwi.txt
# ** file =  zidfs.txt
# ** file =  zlyuw.txt
# ** file =  dnjsf.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/jxhbl/lradw/iglcm
# dirs =  []
# files =  ['equko.py', 'xpulv.txt', 'esyhw.txt', 'wnzzk.py', 'lfesp.py', 'xpfmw.py', 'cnems.py', 'fenje.txt']
# ** file =  equko.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/jxhbl/tpdvr
# dirs =  ['mchbv', 'wrgbg']
# files =  ['pfoyt.py', 'xsedu.txt', 'qmrnz.txt']
# ** file =  pfoyt.py
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/jxhbl/tpdvr/mchbv
# dirs =  []
# files =  []
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/jxhbl/tpdvr/wrgbg
# dirs =  []
# files =  []
# current_dir =  main/taivr/yptwa/xsbzr/hcasz/ilitr/urguw/sjmeg/ddnaa/ckaab
# dirs =  []
# files =  ['krlys.py', 'zppuj.py', 'dlokm.txt']
# ** file =  krlys.py
# current_dir =  main/taivr/yptwa/xsbzr/armfl
# dirs =  []
# files =  ['nhwim.txt', 'zldzs.txt', 'zfdgl.txt', 'bfkjp.txt']
# ** file =  nhwim.txt
# ** file =  zldzs.txt
# ** file =  zfdgl.txt
# ** file =  bfkjp.txt
# current_dir =  main/tgwey
# dirs =  []
# files =  []
# current_dir =  main/ksuvk
# dirs =  ['xjrqt']
# files =  []
# current_dir =  main/ksuvk/xjrqt
# dirs =  ['qjoks', 'qdbqt']
# files =  ['ntdip.txt', 'lbvrl.txt', 'wvtgk.py']
# ** file =  ntdip.txt
# ** file =  lbvrl.txt
# ** file =  wvtgk.py
# current_dir =  main/ksuvk/xjrqt/qjoks
# dirs =  ['lucwg']
# files =  ['gswni.txt', 'kqizu.txt']
# ** file =  gswni.txt
# ** file =  kqizu.txt
# current_dir =  main/ksuvk/xjrqt/qjoks/lucwg
# dirs =  []
# files =  ['rcczp.txt', 'tzpsu.txt']
# ** file =  rcczp.txt
# ** file =  tzpsu.txt
# current_dir =  main/ksuvk/xjrqt/qdbqt
# dirs =  ['prkcp', 'hotgx']
# files =  ['fnxzz.txt']
# ** file =  fnxzz.txt
# current_dir =  main/ksuvk/xjrqt/qdbqt/prkcp
# dirs =  ['dnyyv']
# files =  ['qdugi.txt', 'qkxpf.txt']
# ** file =  qdugi.txt
# ** file =  qkxpf.txt
# current_dir =  main/ksuvk/xjrqt/qdbqt/prkcp/dnyyv
# dirs =  ['rbcbt']
# files =  ['gqjfx.txt', 'nozbp.py', 'jlife.py', 'dbmss.py']
# ** file =  gqjfx.txt
# ** file =  nozbp.py
# current_dir =  main/ksuvk/xjrqt/qdbqt/prkcp/dnyyv/rbcbt
# dirs =  []
# files =  []
# current_dir =  main/ksuvk/xjrqt/qdbqt/hotgx
# dirs =  ['efjkp', 'izwwv']
# files =  ['dudeb.py', 'cpyns.txt']
# ** file =  dudeb.py
# current_dir =  main/ksuvk/xjrqt/qdbqt/hotgx/efjkp
# dirs =  []
# files =  []
# current_dir =  main/ksuvk/xjrqt/qdbqt/hotgx/izwwv
# dirs =  ['xrrlt']
# files =  ['zaxis.py', 'xfqqg.py', 'yhgoq.py']
# ** file =  zaxis.py
# current_dir =  main/ksuvk/xjrqt/qdbqt/hotgx/izwwv/xrrlt
# dirs =  []
# files =  ['kpkop.txt', 'dygkw.txt', 'mbict.txt', 'swmfb.txt']
# ** file =  kpkop.txt
# ** file =  dygkw.txt
# ** file =  mbict.txt
# ** file =  swmfb.txt
# current_dir =  main/mwhci
# dirs =  []
# files =  ['ttopz.py', 'gymxy.txt']
# ** file =  ttopz.py
# current_dir =  main/frtrl
# dirs =  []
# files =  ['eaemw.py', 'gycxp.txt', 'vfiks.txt']
# ** file =  eaemw.py
# current_dir =  main/ddiqo
# dirs =  []
# files =  ['qxbwf.txt']
# ** file =  qxbwf.txt
# current_dir =  main/olmhl
# dirs =  ['mmtsz']
# files =  ['whfbo.txt', 'kgiik.txt', 'bhmcc.txt', 'rnhvd.txt', 'gnaag.txt']
# ** file =  whfbo.txt
# ** file =  kgiik.txt
# ** file =  bhmcc.txt
# ** file =  rnhvd.txt
# ** file =  gnaag.txt
# current_dir =  main/olmhl/mmtsz
# dirs =  ['nujko', 'phcap']
# files =  ['hamfm.py', 'ngutc.py', 'rsolr.py', 'elpwr.py', 'mvrdu.txt', 'xikrv.txt']
# ** file =  hamfm.py
# current_dir =  main/olmhl/mmtsz/nujko
# dirs =  ['ywjxy', 'ywjka', 'bjdpa']
# files =  ['vlzlx.txt']
# ** file =  vlzlx.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjxy
# dirs =  []
# files =  ['ywjow.txt', 'zvlcy.txt', 'danel.txt', 'isljh.py', 'tdktd.txt', 'smpkt.txt']
# ** file =  ywjow.txt
# ** file =  zvlcy.txt
# ** file =  danel.txt
# ** file =  isljh.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka
# dirs =  ['pxjip']
# files =  ['kisdi.py', 'uskqk.txt', 'wpeve.txt', 'llzma.txt', 'ailhc.py', 'zwmpm.txt']
# ** file =  kisdi.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip
# dirs =  ['wthmo']
# files =  ['lmrtv.py', 'fpuyw.txt', 'qshso.txt', 'aniue.py', 'mcvwk.py', 'ssfuy.py']
# ** file =  lmrtv.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo
# dirs =  ['rwwuw', 'wtgrc', 'yaqkg', 'dgypg']
# files =  ['kdfnf.py', 'hjsqc.txt', 'zszcm.txt', 'lcgtq.txt', 'mupic.txt', 'rkrrw.txt', 'ewpru.py', 'wwcga.txt', 'puzpd.py', 'xfalg.txt', 'ytfxp.txt']
# ** file =  kdfnf.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/rwwuw
# dirs =  []
# files =  ['xwmnb.py']
# ** file =  xwmnb.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc
# dirs =  ['mgplg', 'juoxd', 'zfukg', 'kztxg', 'grnfu']
# files =  ['gwqic.py', 'rjhap.txt', 'hckvz.txt', 'qyduf.txt', 'hiyqi.txt', 'smnsc.py', 'nbenj.txt']
# ** file =  gwqic.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg
# dirs =  ['rbyav']
# files =  ['bnlci.txt', 'deetn.txt']
# ** file =  bnlci.txt
# ** file =  deetn.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav
# dirs =  ['yqzsa', 'uaodv', 'ppeir', 'qosgw']
# files =  ['xipxd.py', 'tjwtk.txt', 'yxalw.txt', 'bqscf.txt', 'amgvh.txt', 'bxijj.py', 'nbjiu.txt', 'dkcir.txt', 'ywngw.txt']
# ** file =  xipxd.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/yqzsa
# dirs =  []
# files =  ['ufxbx.txt', 'yrxcm.txt']
# ** file =  ufxbx.txt
# ** file =  yrxcm.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/uaodv
# dirs =  []
# files =  ['lcoui.txt', 'dikzy.py']
# ** file =  lcoui.txt
# ** file =  dikzy.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir
# dirs =  ['vsdfx', 'subdi', 'qyeyy']
# files =  ['hzbta.txt', 'fnsya.txt', 'vjodn.txt']
# ** file =  hzbta.txt
# ** file =  fnsya.txt
# ** file =  vjodn.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/vsdfx
# dirs =  []
# files =  ['pmnyj.txt']
# ** file =  pmnyj.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi
# dirs =  ['afrqp', 'elqwy', 'zljoz', 'hsbbt']
# files =  ['eddpe.txt', 'ojogb.txt', 'maxmd.txt', 'uiwot.py', 'nvcly.txt', 'ybjka.txt', 'wmlla.py', 'sfjei.txt', 'ivfrj.txt', 'ccyrz.py', 'cbdqd.py', 'lazia.txt', 'egyde.txt', 'eihrp.py', 'cqugd.py', 'ptykj.py', 'rebkn.txt', 'fwxhe.py']
# ** file =  eddpe.txt
# ** file =  ojogb.txt
# ** file =  maxmd.txt
# ** file =  uiwot.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp
# dirs =  ['iaujh']
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh
# dirs =  ['jqnsz', 'jqjsg', 'addrx']
# files =  ['hbsuz.txt', 'rzsqn.txt', 'yadbj.txt', 'edamr.py']
# ** file =  hbsuz.txt
# ** file =  rzsqn.txt
# ** file =  yadbj.txt
# ** file =  edamr.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqnsz
# dirs =  []
# files =  ['ihdto.py', 'cfbxr.py', 'lcgml.txt', 'jqeou.py']
# ** file =  ihdto.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg
# dirs =  ['zbzvv', 'xriod']
# files =  ['wpqqa.py', 'waxgh.txt', 'fpnip.txt', 'goiyc.txt', 'nnrrb.py']
# ** file =  wpqqa.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/zbzvv
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod
# dirs =  ['dvban']
# files =  ['kxcas.txt', 'ifjxk.py', 'mbsnb.txt']
# ** file =  kxcas.txt
# ** file =  ifjxk.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod/dvban
# dirs =  ['jhpib', 'gufln']
# files =  ['rkqzh.txt']
# ** file =  rkqzh.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod/dvban/jhpib
# dirs =  ['ufrhp']
# files =  ['eyohd.txt', 'tkpoz.txt']
# ** file =  eyohd.txt
# ** file =  tkpoz.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod/dvban/jhpib/ufrhp
# dirs =  []
# files =  ['nfxlv.txt', 'hglwu.txt']
# ** file =  nfxlv.txt
# ** file =  hglwu.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod/dvban/gufln
# dirs =  ['yklwn']
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod/dvban/gufln/yklwn
# dirs =  ['efemx']
# files =  ['xfymd.txt']
# ** file =  xfymd.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod/dvban/gufln/yklwn/efemx
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/addrx
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/elqwy
# dirs =  []
# files =  ['huzxi.txt', 'svkqp.txt', 'wbfcq.txt', 'fcibk.txt']
# ** file =  huzxi.txt
# ** file =  svkqp.txt
# ** file =  wbfcq.txt
# ** file =  fcibk.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz
# dirs =  ['sgmoj', 'xrvnu', 'kgdme', 'hsndh']
# files =  ['tkmtk.py', 'cjsev.txt', 'pkcoh.txt', 'swqks.py', 'judks.txt', 'xixnf.txt', 'nhzsu.txt', 'hjlgw.txt', 'lrshd.txt']
# ** file =  tkmtk.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/sgmoj
# dirs =  []
# files =  ['zxoah.py', 'oteke.py']
# ** file =  zxoah.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/xrvnu
# dirs =  []
# files =  ['rovjs.py', 'dxvcb.py', 'gbevo.txt']
# ** file =  rovjs.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme
# dirs =  ['evnvn', 'jhhbu']
# files =  ['pfxyh.txt', 'dtlmp.txt', 'xdsja.txt', 'sgtmk.txt', 'euduy.py', 'thrcn.py', 'bdwkq.txt', 'vwicr.py', 'natoh.txt', 'mfbag.txt', 'rlccj.txt', 'pxcim.txt', 'efipd.py', 'uykvs.txt', 'qnpjo.txt']
# ** file =  pfxyh.txt
# ** file =  dtlmp.txt
# ** file =  xdsja.txt
# ** file =  sgtmk.txt
# ** file =  euduy.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/evnvn
# dirs =  ['axqur']
# files =  ['zhvfc.txt', 'cgsyt.txt']
# ** file =  zhvfc.txt
# ** file =  cgsyt.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/evnvn/axqur
# dirs =  ['itkcz']
# files =  ['snjsf.py', 'lrzdq.txt', 'karzq.txt', 'fykwk.txt', 'dsmgr.txt', 'pxmdu.txt', 'exqbe.txt']
# ** file =  snjsf.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/evnvn/axqur/itkcz
# dirs =  []
# files =  ['rvjcx.py', 'mggvs.txt', 'hoyms.py', 'nnzmq.py']
# ** file =  rvjcx.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu
# dirs =  ['rnqwd', 'dufxr', 'khutz']
# files =  ['tkkmf.txt', 'jckmn.txt', 'abkxq.txt', 'mvdbn.txt', 'ddhit.txt']
# ** file =  tkkmf.txt
# ** file =  jckmn.txt
# ** file =  abkxq.txt
# ** file =  mvdbn.txt
# ** file =  ddhit.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd
# dirs =  ['purto', 'cykbq']
# files =  ['bjtsl.txt', 'sbjht.py', 'obcpa.py']
# ** file =  bjtsl.txt
# ** file =  sbjht.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto
# dirs =  ['bkfog', 'hmnro', 'bsgqc', 'mwhkt']
# files =  ['uvulr.py', 'kycri.txt', 'ratqg.txt', 'ssjjr.py', 'ihpqq.txt', 'zclmh.py', 'zbqui.py', 'cyktn.txt', 'uzvga.txt', 'qqyty.txt', 'sjhjd.py', 'ppher.txt', 'trope.py']
# ** file =  uvulr.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog
# dirs =  ['rvsfo']
# files =  ['hkakk.txt', 'rjrcl.txt', 'dndhe.py', 'drkat.py']
# ** file =  hkakk.txt
# ** file =  rjrcl.txt
# ** file =  dndhe.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo
# dirs =  ['gvbnv', 'rpnzm']
# files =  ['girkd.py']
# ** file =  girkd.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/gvbnv
# dirs =  []
# files =  ['qjicg.py']
# ** file =  qjicg.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm
# dirs =  ['ilogc', 'kafov', 'sydlz']
# files =  ['wqsqb.py', 'cdlnj.py', 'kholn.py', 'kxafz.py', 'xolho.txt']
# ** file =  wqsqb.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/ilogc
# dirs =  ['reshp']
# files =  ['qtadz.py']
# ** file =  qtadz.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/ilogc/reshp
# dirs =  []
# files =  ['raznl.py', 'wevmv.py', 'vbxad.txt', 'zqwbg.txt', 'czkpi.py']
# ** file =  raznl.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov
# dirs =  ['gndkk', 'iites']
# files =  ['uifjw.py', 'gkqve.txt']
# ** file =  uifjw.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/gndkk
# dirs =  ['rdwhc']
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/gndkk/rdwhc
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites
# dirs =  ['yywbw', 'ygtox']
# files =  ['ebguw.txt']
# ** file =  ebguw.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/yywbw
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox
# dirs =  ['bpmhg', 'rhvqn']
# files =  ['gqvel.txt']
# ** file =  gqvel.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/bpmhg
# dirs =  []
# files =  ['ssizd.py', 'xoaoa.py']
# ** file =  ssizd.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/rhvqn
# dirs =  ['ggfcr']
# files =  ['lxlbl.py', 'tftye.txt', 'hafgb.txt']
# ** file =  lxlbl.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/rhvqn/ggfcr
# dirs =  ['bmihb', 'kxyxy']
# files =  ['qqqpe.py', 'xclus.txt', 'cgzfk.py', 'taevp.py']
# ** file =  qqqpe.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/rhvqn/ggfcr/bmihb
# dirs =  []
# files =  ['qnune.txt', 'qritj.txt']
# ** file =  qnune.txt
# ** file =  qritj.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/rhvqn/ggfcr/kxyxy
# dirs =  ['qrxwt', 'inhuj']
# files =  ['rbykh.txt', 'ziymt.txt', 'tkjfg.txt', 'dedkl.txt', 'xxgjq.txt']
# ** file =  rbykh.txt
# ** file =  ziymt.txt
# ** file =  tkjfg.txt
# ** file =  dedkl.txt
# ** file =  xxgjq.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/rhvqn/ggfcr/kxyxy/qrxwt
# dirs =  []
# files =  ['djwiq.py']
# ** file =  djwiq.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/kafov/iites/ygtox/rhvqn/ggfcr/kxyxy/inhuj
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/sydlz
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/hmnro
# dirs =  ['jtmnb']
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/hmnro/jtmnb
# dirs =  []
# files =  ['rvzlj.py', 'ontkl.txt']
# ** file =  rvzlj.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bsgqc
# dirs =  ['ujtgh']
# files =  ['zjedz.txt', 'xljbc.txt']
# ** file =  zjedz.txt
# ** file =  xljbc.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bsgqc/ujtgh
# dirs =  ['tyapv']
# files =  ['aqqzt.py', 'zltuv.txt', 'uhuvh.py', 'jyckp.txt']
# ** file =  aqqzt.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bsgqc/ujtgh/tyapv
# dirs =  ['rbmqk', 'splzy']
# files =  ['zatko.txt', 'sxsij.txt', 'nglat.txt', 'vzkic.py', 'dwwlp.py', 'tpycd.txt', 'edfgq.txt', 'mrkmf.py', 'xaeym.txt', 'nqcnq.txt']
# ** file =  zatko.txt
# ** file =  sxsij.txt
# ** file =  nglat.txt
# ** file =  vzkic.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bsgqc/ujtgh/tyapv/rbmqk
# dirs =  []
# files =  ['omslv.txt']
# ** file =  omslv.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bsgqc/ujtgh/tyapv/splzy
# dirs =  []
# files =  ['smzhc.txt']
# ** file =  smzhc.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/mwhkt
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/cykbq
# dirs =  []
# files =  ['pdxto.txt']
# ** file =  pdxto.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr
# dirs =  ['jbsmx', 'sxojq', 'xmqfi', 'xksyt', 'hlgup', 'xroxl']
# files =  ['heuap.txt', 'kesve.txt', 'rselz.txt', 'mvznr.py']
# ** file =  heuap.txt
# ** file =  kesve.txt
# ** file =  rselz.txt
# ** file =  mvznr.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/jbsmx
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/sxojq
# dirs =  ['rjekz']
# files =  ['grfwe.txt', 'frdru.py', 'ltedx.py', 'nugyo.txt']
# ** file =  grfwe.txt
# ** file =  frdru.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/sxojq/rjekz
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xmqfi
# dirs =  []
# files =  ['uczpf.txt', 'ssflw.txt']
# ** file =  uczpf.txt
# ** file =  ssflw.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xksyt
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/hlgup
# dirs =  ['kzoko', 'auqky']
# files =  ['wxxzu.py', 'mozyb.txt', 'voshk.txt', 'cycho.txt']
# ** file =  wxxzu.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/hlgup/kzoko
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/hlgup/auqky
# dirs =  []
# files =  ['afymg.py']
# ** file =  afymg.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl
# dirs =  ['abslw', 'rgunj']
# files =  ['wrxre.txt', 'ybxzk.txt', 'viutj.txt', 'lagpy.py', 'xwnhn.txt']
# ** file =  wrxre.txt
# ** file =  ybxzk.txt
# ** file =  viutj.txt
# ** file =  lagpy.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/abslw
# dirs =  []
# files =  ['urqac.py']
# ** file =  urqac.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj
# dirs =  ['bdcjg']
# files =  ['hjzzj.txt', 'znkxz.txt', 'tjkav.txt']
# ** file =  hjzzj.txt
# ** file =  znkxz.txt
# ** file =  tjkav.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg
# dirs =  ['nsyus', 'vkntp', 'xpmcm', 'rydrk', 'ktkfx']
# files =  ['lgunz.py', 'onkcs.txt']
# ** file =  lgunz.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/nsyus
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/vkntp
# dirs =  ['rjqjr']
# files =  ['wutxm.txt', 'nujsg.py', 'enqxz.txt']
# ** file =  wutxm.txt
# ** file =  nujsg.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/vkntp/rjqjr
# dirs =  []
# files =  ['ugvgv.txt', 'megyo.py']
# ** file =  ugvgv.txt
# ** file =  megyo.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/xpmcm
# dirs =  []
# files =  ['eslhq.py']
# ** file =  eslhq.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/rydrk
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/ktkfx
# dirs =  []
# files =  ['vfylr.txt', 'mkydd.py']
# ** file =  vfylr.txt
# ** file =  mkydd.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/khutz
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/hsndh
# dirs =  []
# files =  ['baffg.txt']
# ** file =  baffg.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/hsbbt
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/qyeyy
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/qosgw
# dirs =  ['hxnor']
# files =  ['qpajn.py', 'hcibv.txt']
# ** file =  qpajn.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/qosgw/hxnor
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/juoxd
# dirs =  ['efbru']
# files =  ['cdizf.txt', 'duwbk.txt', 'hjgdf.py', 'vnysh.txt']
# ** file =  cdizf.txt
# ** file =  duwbk.txt
# ** file =  hjgdf.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/juoxd/efbru
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg
# dirs =  ['jvmme', 'vydse', 'ttmjw', 'cazio', 'rvuph', 'axlsq']
# files =  ['yqthe.py', 'badbu.txt', 'flder.txt', 'yxzsn.txt', 'xcarh.py', 'lkale.txt', 'ooyge.txt', 'exewx.py', 'zqbnu.txt', 'wggct.py', 'eqozh.txt', 'yzjqu.txt', 'ncajz.py', 'vtsov.py']
# ** file =  yqthe.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme
# dirs =  ['kehsm', 'vynzv', 'ipboa', 'eayzq', 'wvwva']
# files =  ['peoqq.txt', 'ndmba.txt', 'ycnmt.py']
# ** file =  peoqq.txt
# ** file =  ndmba.txt
# ** file =  ycnmt.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/kehsm
# dirs =  []
# files =  ['racex.py']
# ** file =  racex.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/vynzv
# dirs =  []
# files =  ['cnlvc.txt', 'qtxsm.py']
# ** file =  cnlvc.txt
# ** file =  qtxsm.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/ipboa
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq
# dirs =  ['nuiwj', 'wfnda', 'isyki', 'tixoq']
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq/nuiwj
# dirs =  []
# files =  ['qtfig.py']
# ** file =  qtfig.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq/wfnda
# dirs =  []
# files =  ['bkfpc.txt', 'wenln.py', 'myqbc.txt', 'lzcsc.txt']
# ** file =  bkfpc.txt
# ** file =  wenln.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq/isyki
# dirs =  []
# files =  ['ooakq.txt', 'tzfue.txt', 'sxnyt.py', 'pqzao.py']
# ** file =  ooakq.txt
# ** file =  tzfue.txt
# ** file =  sxnyt.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq/tixoq
# dirs =  ['lldpv']
# files =  ['upvvt.txt', 'jzzng.txt']
# ** file =  upvvt.txt
# ** file =  jzzng.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq/tixoq/lldpv
# dirs =  ['hbsiz']
# files =  ['nzmgi.py', 'hzgem.py', 'qxkag.py']
# ** file =  nzmgi.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/eayzq/tixoq/lldpv/hbsiz
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva
# dirs =  ['nosvo', 'jebnq', 'bufuy']
# files =  ['fkxut.txt', 'cyasy.txt', 'ehaxe.py', 'fwutv.py', 'hxbrt.txt', 'ghtwx.py', 'oqgva.txt']
# ** file =  fkxut.txt
# ** file =  cyasy.txt
# ** file =  ehaxe.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva/nosvo
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva/jebnq
# dirs =  ['phcud', 'kjmeo']
# files =  ['hkmde.txt']
# ** file =  hkmde.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva/jebnq/phcud
# dirs =  ['vllzq']
# files =  ['yonbu.txt', 'oehnz.py']
# ** file =  yonbu.txt
# ** file =  oehnz.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva/jebnq/phcud/vllzq
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva/jebnq/kjmeo
# dirs =  []
# files =  ['ovpoz.txt', 'jfckr.py', 'obnym.txt']
# ** file =  ovpoz.txt
# ** file =  jfckr.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/jvmme/wvwva/bufuy
# dirs =  []
# files =  ['rhfsy.txt']
# ** file =  rhfsy.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/vydse
# dirs =  ['uuzho']
# files =  ['yzhtw.py']
# ** file =  yzhtw.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/vydse/uuzho
# dirs =  ['popcu']
# files =  ['duvqv.txt']
# ** file =  duvqv.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/vydse/uuzho/popcu
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/ttmjw
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/cazio
# dirs =  ['sosdj']
# files =  ['zxxeu.py', 'zkakj.py']
# ** file =  zxxeu.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/cazio/sosdj
# dirs =  ['uuyrs', 'rcsvd', 'yujjk']
# files =  ['dzkem.txt', 'cbmii.txt', 'kjava.py']
# ** file =  dzkem.txt
# ** file =  cbmii.txt
# ** file =  kjava.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/cazio/sosdj/uuyrs
# dirs =  []
# files =  ['lzvgo.py']
# ** file =  lzvgo.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/cazio/sosdj/rcsvd
# dirs =  []
# files =  ['lmyue.py']
# ** file =  lmyue.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/cazio/sosdj/yujjk
# dirs =  []
# files =  ['tqbxn.txt', 'tmonk.py', 'tglpv.txt', 'jrpje.txt']
# ** file =  tqbxn.txt
# ** file =  tmonk.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/rvuph
# dirs =  []
# files =  ['fvrwq.txt']
# ** file =  fvrwq.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/zfukg/axlsq
# dirs =  []
# files =  ['ojzky.txt']
# ** file =  ojzky.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg
# dirs =  ['qwlrx']
# files =  ['ibude.txt', 'cnfnj.txt', 'olwiq.txt']
# ** file =  ibude.txt
# ** file =  cnfnj.txt
# ** file =  olwiq.txt
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx
# dirs =  ['dhnor', 'drovd', 'nfcxf', 'djozj', 'lirot']
# files =  ['blvtq.py', 'jskvm.txt', 'hzhfn.py', 'igtmf.txt', 'wajrg.txt', 'nwjdv.txt', 'edmiy.txt', 'loqtf.py', 'gyvur.txt', 'hstyv.py', 'vjhld.txt']
# ** file =  blvtq.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/dhnor
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/drovd
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/nfcxf
# dirs =  []
# files =  ['uvmef.py', 'jglht.txt']
# ** file =  uvmef.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/djozj
# dirs =  []
# files =  ['vcipo.txt', 'xjsai.txt', 'ptdnq.py']
# ** file =  vcipo.txt
# ** file =  xjsai.txt
# ** file =  ptdnq.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/lirot
# dirs =  []
# files =  ['auwzy.py']
# ** file =  auwzy.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/grnfu
# dirs =  []
# files =  ['cubok.py']
# ** file =  cubok.py
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/yaqkg
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/dgypg
# dirs =  []
# files =  []
# current_dir =  main/olmhl/mmtsz/nujko/bjdpa
# dirs =  []
# files =  ['lfxys.txt']
# ** file =  lfxys.txt
# current_dir =  main/olmhl/mmtsz/phcap
# dirs =  []
# files =  ['etheg.txt', 'udied.py']
# ** file =  etheg.txt
# ** file =  udied.py
# current_dir =  main/lqbli
# dirs =  ['otofk']
# files =  ['qybbd.txt']
# ** file =  qybbd.txt
# current_dir =  main/lqbli/otofk
# dirs =  ['zsojz', 'armko']
# files =  ['hbxjv.txt', 'ofcia.txt', 'akmok.py', 'ybrdw.py', 'pbidc.py']
# ** file =  hbxjv.txt
# ** file =  ofcia.txt
# ** file =  akmok.py
# current_dir =  main/lqbli/otofk/zsojz
# dirs =  []
# files =  ['yqlyh.txt']
# ** file =  yqlyh.txt
# current_dir =  main/lqbli/otofk/armko
# dirs =  ['svrbq', 'ufenh']
# files =  ['kchnx.py', 'nciua.txt', 'dofzv.txt', 'ohwpa.txt', 'npucw.txt']
# ** file =  kchnx.py
# current_dir =  main/lqbli/otofk/armko/svrbq
# dirs =  []
# files =  []
# current_dir =  main/lqbli/otofk/armko/ufenh
# dirs =  []
# files =  []
# current_dir =  main/jrczb
# dirs =  []
# files =  ['ifupb.txt']
# ** file =  ifupb.txt
# current_dir =  main/wkwll
# dirs =  []
# files =  ['tfncr.txt']
# ** file =  tfncr.txt
# current_dir =  main/ybebm
# dirs =  []
# files =  ['rklqu.txt']
# ** file =  rklqu.txt
# current_dir =  main/zduna
# dirs =  ['ywucw', 'enfpw']
# files =  ['sqeuh.txt']
# ** file =  sqeuh.txt
# current_dir =  main/zduna/ywucw
# dirs =  ['tagpz', 'rcacj']
# files =  ['nrkfg.txt', 'zzraa.txt', 'rwejw.py', 'buxwc.txt', 'kmiuh.txt', 'ixrqq.py', 'oxauw.txt', 'rjjzv.py']
# ** file =  nrkfg.txt
# ** file =  zzraa.txt
# ** file =  rwejw.py
# current_dir =  main/zduna/ywucw/tagpz
# dirs =  []
# files =  []
# current_dir =  main/zduna/ywucw/rcacj
# dirs =  []
# files =  ['syitm.txt']
# ** file =  syitm.txt
# current_dir =  main/zduna/enfpw
# dirs =  []
# files =  []
# current_dir =  main/afkgv
# dirs =  []
# files =  ['bxdnn.py']
# ** file =  bxdnn.py
# current_dir =  main/hgyoc
# dirs =  ['yfdwy', 'ycbxr', 'tztsf', 'ilwwv', 'kwawh']
# files =  ['gvyia.py', 'diyzm.txt', 'xzwbm.txt', 'azghn.txt', 'jeejo.txt', 'skjvb.txt', 'ogoff.txt', 'xdwty.txt', 'kwfhy.txt', 'avzvc.py', 'bnunx.py', 'mcesa.py']
# ** file =  gvyia.py
# current_dir =  main/hgyoc/yfdwy
# dirs =  []
# files =  ['ortfz.txt']
# ** file =  ortfz.txt
# current_dir =  main/hgyoc/ycbxr
# dirs =  ['ivjta', 'xkvcg', 'kokzg', 'jpjxk']
# files =  ['qzqyg.txt', 'kslju.txt', 'tdhup.txt']
# ** file =  qzqyg.txt
# ** file =  kslju.txt
# ** file =  tdhup.txt
# current_dir =  main/hgyoc/ycbxr/ivjta
# dirs =  []
# files =  ['kfllc.py']
# ** file =  kfllc.py
# current_dir =  main/hgyoc/ycbxr/xkvcg
# dirs =  []
# files =  ['clpnh.txt']
# ** file =  clpnh.txt
# current_dir =  main/hgyoc/ycbxr/kokzg
# dirs =  []
# files =  []
# current_dir =  main/hgyoc/ycbxr/jpjxk
# dirs =  []
# files =  []
# current_dir =  main/hgyoc/tztsf
# dirs =  []
# files =  ['vegzp.txt', 'iynbe.txt']
# ** file =  vegzp.txt
# ** file =  iynbe.txt
# current_dir =  main/hgyoc/ilwwv
# dirs =  []
# files =  ['psxra.txt']
# ** file =  psxra.txt
# current_dir =  main/hgyoc/kwawh
# dirs =  ['jxtqa', 'uunbz', 'hapry', 'rzgzv']
# files =  ['lrzxd.py', 'bxlns.txt']
# ** file =  lrzxd.py
# current_dir =  main/hgyoc/kwawh/jxtqa
# dirs =  []
# files =  []
# current_dir =  main/hgyoc/kwawh/uunbz
# dirs =  []
# files =  ['mnnoy.txt', 'biqwd.txt', 'nkvij.txt']
# ** file =  mnnoy.txt
# ** file =  biqwd.txt
# ** file =  nkvij.txt
# current_dir =  main/hgyoc/kwawh/hapry
# dirs =  []
# files =  ['mejcl.py', 'pevsg.py']
# ** file =  mejcl.py
# current_dir =  main/hgyoc/kwawh/rzgzv
# dirs =  []
# files =  ['yraxd.py', 'grbfr.txt']
# ** file =  yraxd.py
# current_dir =  main/sitdc
# dirs =  []
# files =  ['kvayn.py', 'vucrc.txt']
# ** file =  kvayn.py
# current_dir =  main/zyczx
# dirs =  []
# files =  ['wftkz.txt', 'dqiag.txt', 'edqml.txt', 'njkyn.py']
# ** file =  wftkz.txt
# ** file =  dqiag.txt
# ** file =  edqml.txt
# ** file =  njkyn.py
# answer =  ['main/', 'main/afkgv', 'main/frtrl', 'main/hgyoc', 'main/hgyoc/kwawh', 'main/hgyoc/kwawh/hapry', 'main/hgyoc/kwawh/rzgzv', 'main/hgyoc/ycbxr/ivjta', 'main/ksuvk/xjrqt', 'main/ksuvk/xjrqt/qdbqt/hotgx', 'main/ksuvk/xjrqt/qdbqt/hotgx/izwwv', 'main/ksuvk/xjrqt/qdbqt/prkcp/dnyyv', 'main/lqbli/otofk', 'main/lqbli/otofk/armko', 'main/mwhci', 'main/olmhl/mmtsz', 'main/olmhl/mmtsz/nujko/ywjka', 'main/olmhl/mmtsz/nujko/ywjka/pxjip', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/rwwuw', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/grnfu', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/juoxd', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/djozj', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/lirot', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/kztxg/qwlrx/nfcxf', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqjsg/xriod', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/afrqp/iaujh/jqnsz', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/evnvn/axqur', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/evnvn/axqur/itkcz', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/hlgup', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/hlgup/auqky', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/sxojq', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/abslw', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/ktkfx', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/vkntp', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/vkntp/rjqjr', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/dufxr/xroxl/rgunj/bdcjg/xpmcm', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/gvbnv', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/ilogc', 'main/olmhl/mmtsz/nujko/ywjka/pxjip/wthmo/wtgrc/mgplg/rbyav/ppeir/subdi/zljoz/kgdme/jhhbu/rnqwd/purto/bkfog/rvsfo/rpnzm/ilogc/re ...

# %% [markdown]
# Лямбда функции предоставляют нам удобный способ создать функцию «прямо на месте».
# Но иногда, когда нужно создавать много однотипных лямбда функций, еще удобнее будет создать функцию, которая будет их генерировать.
#
# Реализуйте функцию mod_checker(x, mod=0), которая будет генерировать лямбда функцию от одного аргумента y, которая будет возвращать True, если остаток от деления y на x равен mod, и False иначе.

# %% [markdown]
# Пример использования:
#
# mod_3 = mod_checker(3)
#
# print(mod_3(3)) # True
#
# print(mod_3(4)) # False
#
# mod_3_1 = mod_checker(3, 1)
# print(mod_3_1(4)) # True

# %%
from functools import partial

def mod_checker(mod, ostatok=0):
    return lambda x: x % mod == ostatok


mod_3 = mod_checker(3)

print(mod_3(3)) # True
print(mod_3(4)) # False

mod_3_1 = mod_checker(3, 1)
print(mod_3_1(4)) # True
# Out:
# True
# False
# True

# %%
import sys
print(sys.__doc__)
# Out:
# This module provides access to some objects used or maintained by the
# interpreter and to functions that interact strongly with the interpreter.
#
# Dynamic objects:
#
# argv -- command line arguments; argv[0] is the script pathname if known
# path -- module search path; path[0] is the script directory, else ''
# modules -- dictionary of loaded modules
#
# displayhook -- called to show results in an interactive session
# excepthook -- called to handle any uncaught exception other than SystemExit
#   To customize printing in an interactive session or to install a custom
#   top-level exception handler, assign other functions to replace these.
#
# stdin -- standard input file object; used by input()
# stdout -- standard output file object; used by print()
# stderr -- standard error object; used for error messages
#   By assigning other file objects (or objects that behave like files)
#   to these, it is possible to redirect all of the interpreter's I/O.
#
# last_type -- type of last uncaught exception
# last_value -- value of last uncaught exception
# last_traceback -- traceback of last uncaught exception
#   These three are only available in an interactive session after a
#   traceback has been printed.
#
# Static objects:
#
# builtin_module_names -- tuple of module names built into this interpreter
# copyright -- copyright notice pertaining to this interpreter
# exec_prefix -- prefix used to find the machine-specific Python library
# executable -- absolute path of the executable binary of the Python interpreter
# float_info -- a named tuple with information about the float implementation.
# float_repr_style -- string indicating the style of repr() output for floats
# hash_info -- a named tuple with information about the hash algorithm.
# hexversion -- version information encoded as a single integer
# implementation -- Python implementation information.
# int_info -- a named tuple with information about the int implementation.
# maxsize -- the largest supported length of containers.
# maxunicode -- the value of the largest Unicode code point
# platform -- platform identifier
# prefix -- prefix used to find the Python library
# thread_info -- a named tuple with information about the thread implementation.
# version -- the version of this interpreter as a string
# version_info -- version information as a named tuple
# __stdin__ -- the original stdin; don't touch!
# __stdout__ -- the original stdout; don't touch!
# __stderr__ -- the original stderr; don't touch!
# __displayhook__ -- the original displayhook; don't touch!
# __excepthook__ -- the original excepthook; don't touch!
#
# Functions:
#
# displayhook() -- print an object to the screen, and save it in builtins._
# excepthook() -- print an exception and its traceback to sys.stderr
# exc_info() -- return thread-safe information about the current exception
# exit() -- exit the interpreter by raising SystemExit
# getdlopenflags() -- returns flags to be used for dlopen() calls
# getprofile() -- get the global profiling function
# getrefcount() -- return the reference count for an object (plus one :-)
# getrecursionlimit() -- return the max recursion depth for the interpreter
# getsizeof() -- return the size of an object in bytes
# gettrace() -- get the global debug tracing function
# setdlopenflags() -- set the flags to be used for dlopen() calls
# setprofile() -- set the global profiling function
# setrecursionlimit() -- set the max recursion depth for the interpreter
# settrace() -- set the global debug tracing function

# %%
sys.getrefcount.__doc__
# Out:
# 'Return the reference count of object.\n\nThe count returned is generally one higher than you might expect,\nbecause it includes the (temporary) reference as an argument to\ngetrefcount().'

# %% [markdown]
# Вашей программе на вход подаются три строки s, a, b, состоящие из строчных латинских букв.
# За одну операцию вы можете заменить все вхождения строки a в строку s на строку b.
#
# Например, s = "abab", a = "ab", b = "ba", тогда после выполнения одной операции строка s перейдет в строку "baba", после выполнения двух и операций – в строку "bbaa", и дальнейшие операции не будут изменять строку s.
#
# Необходимо узнать, после какого минимального количества операций в строке s не останется вхождений строки a. Если операций потребуется более 1000, выведите Impossible.
#
# Выведите одно число – минимальное число операций, после применения которых в строке s не останется вхождений строки a, или Impossible, если операций потребуется более 1000.
#
# Условие задачи было изменено 12.09.2018
# Sample Input 1:
# ababa
# a
# b
# Sample Output 1:
# 1
# Sample Input 2:
# ababa
# b
# a
# Sample Output 2:
# 1
# Sample Input 3:
# ababa
# c
# c
# Sample Output 3:
# 0
# Sample Input 4:
# ababac
# c
# c
# Sample Output 4:
# Impossible

# %%
s, a, b = input().split()
# Out:
# sdf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 s, a, b = input().split()
#
# ValueError: not enough values to unpack (expected 3, got 1)
